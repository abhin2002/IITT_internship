jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01802.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02425.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02425.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01508.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01508.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01512.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01512.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00229.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00229.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00909.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00909.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01716.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01716.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02469.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02469.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01805.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01805.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01176.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01176.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01998.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01998.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01592.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01592.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00618.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00618.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02511.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02511.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01966.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01966.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00015.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00015.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01669.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01669.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02097.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02097.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02260.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02260.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00572.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00572.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02297.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02297.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00741.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00741.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00595.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00595.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02598.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02598.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00428.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00428.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01852.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01852.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00995.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00995.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00858.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00858.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01235.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01235.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02552.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02552.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02075.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02075.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00827.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00827.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01272.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01272.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00673.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00673.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00521.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00521.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00799.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00799.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01859.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01859.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00560.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00560.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00749.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00749.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00213.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00213.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00122.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00122.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02187.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02187.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01889.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01889.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01941.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01941.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02402.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02402.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00757.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00757.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02503.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02503.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01593.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01593.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02558.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02558.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02236.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02236.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00207.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00207.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02015.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02015.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00710.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00710.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00524.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00524.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01604.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01604.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00791.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00791.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00186.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00186.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00466.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00466.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00737.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00737.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01771.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01771.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/02247.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 02247.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00680.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00680.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01052.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01052.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/00232.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 00232.jpg
# ['/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_imgs/01559.jpg']
# ...load U2NET---173.6 MB
# Inferencing: 01559.jpg

# %%
import os
import xml.etree.ElementTree as ET
import numpy as np
from PIL import Image

def create_original_sized_mask(cropped_mask, original_image_path, extended_coords, output_path):
    # Open the original image to get its dimensions
    original_image = Image.open(original_image_path)
    original_width, original_height = original_image.size

    # Create a full zero mask with the original image dimensions
    original_mask = Image.new('L', (original_width, original_height), 0)  # 'L' mode for single channel (grayscale)

    # Ensure the cropped mask is single-channel
    if cropped_mask.mode != 'L':
        cropped_mask = cropped_mask.convert('L')

    # Convert images to numpy arrays
    cropped_mask_array = np.array(cropped_mask)
    original_mask_array = np.array(original_mask)

    y_min, y_max, x_min, x_max = extended_coords

    # Ensure the mask is placed within the bounds of the original mask
    original_mask_array[y_min:y_max, x_min:x_max] = cropped_mask_array

    # Convert the array back to an image
    original_mask = Image.fromarray(original_mask_array)

    # Save the mask
    original_mask.save(output_path)

def get_extended_coordinates(annotation_path, image_width, image_height):
    try:
        # Parse the annotation XML file
        tree = ET.parse(annotation_path)
        root = tree.getroot()

        # Get the bounding box coordinates
        bbox = root.find('object').find('bndbox')
        xmin = int(bbox.find('xmin').text)
        ymin = int(bbox.find('ymin').text)
        xmax = int(bbox.find('xmax').text)
        ymax = int(bbox.find('ymax').text)

        # Calculate the extended cropping coordinates using the provided logic
        x, y, w, h = xmin, ymin, xmax - xmin, ymax - ymin
        y_min = int(y - (h / 4))
        y_max = int(y + h + (h / 4))
        x_min = int(x - (w / 4))
        x_max = int(x + w + (w / 4))

        # Ensure the coordinates are within the image bounds
        y_min = max(0, y_min)
        y_max = min(image_height, y_max)
        x_min = max(0, x_min)
        x_max = min(image_width, x_max)

        return y_min, y_max, x_min, x_max

    except AttributeError:
        # Log the filename if the expected XML structure is not found
        with open('error_log.txt', 'a') as f:
            f.write(f"Error processing {annotation_path}: 'object' tag not found\n")
        return None
    except Exception as e:
        # Handle other exceptions gracefully if needed
        with open('error_log.txt', 'a') as f:
            f.write(f"Error processing {annotation_path}: {str(e)}\n")
        return None

def process_images(image_dir, annotation_dir, cropped_mask_dir, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Get sorted list of files in annotation directory
    annotation_files = sorted(os.listdir(annotation_dir))

    # Process each annotation file
    for annotation_filename in annotation_files:
        if annotation_filename.endswith('.xml'):
            base_name = annotation_filename[:-4]
            image_path = os.path.join(image_dir, base_name + '.jpg')
            annotation_path = os.path.join(annotation_dir, annotation_filename)
            cropped_mask_path = os.path.join(cropped_mask_dir, 'croped_mask' + base_name + '.png')  # Adjusted mask filename

            if not os.path.exists(image_path) or not os.path.exists(cropped_mask_path):
                print(f"Missing corresponding image or mask for {annotation_filename}")
                continue

            # Open the original image to get its dimensions
            original_image = Image.open(image_path)
            original_width, original_height = original_image.size

            # Get the extended coordinates
            extended_coords = get_extended_coordinates(annotation_path, original_width, original_height)

            if extended_coords:
                # Load the cropped mask
                cropped_mask = Image.open(cropped_mask_path)

                # Create and save the original-sized mask
                output_path = os.path.join(output_dir, base_name + '_original_size_mask.png')
                create_original_sized_mask(cropped_mask, image_path, extended_coords, output_path)
                print(f"Original-sized mask saved: {output_path}")

image_dir = '/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/img'
annotation_dir = '/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/xml'
cropped_mask_dir = '/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/croped_mask'
output_dir = '/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask'

process_images(image_dir, annotation_dir, cropped_mask_dir, output_dir)
# Out:
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00001_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00002_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00003_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00004_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00005_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00006_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00007_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00008_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00009_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00010_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00011_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00012_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00013_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00014_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00015_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00016_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00017_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00018_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00019_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00020_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00021_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00022_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00023_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00024_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00025_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00026_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00027_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00028_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00029_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00030_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00031_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00032_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00033_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00034_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00035_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00036_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00037_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00038_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00039_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00040_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00041_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00042_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00043_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00044_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00045_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00046_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00047_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00048_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00049_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00050_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00051_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00052_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00053_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00054_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00055_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00056_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00057_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00058_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00059_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00060_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00061_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00062_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00063_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00064_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00065_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00066_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00067_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00068_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00069_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00070_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00071_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00072_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00073_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00074_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00075_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00076_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00077_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00078_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00079_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00080_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00081_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00082_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00083_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00084_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00085_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00086_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00087_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00088_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00089_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00090_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00091_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00092_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00093_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00094_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00095_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00096_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00097_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00098_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00099_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00100_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00101_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00102_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00103_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00104_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00105_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00106_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00107_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00108_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00109_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00110_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00111_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00112_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00113_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00114_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00115_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00116_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00117_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00118_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00119_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00120_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00121_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00122_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00123_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00124_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00125_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00126_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00127_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00128_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00129_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00130_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00131_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00132_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00133_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00134_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00135_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00136_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00137_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00138_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00139_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00140_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00141_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00142_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00143_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00144_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00145_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00146_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00147_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00148_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00149_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00150_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00151_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00152_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00153_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00154_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00155_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00156_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00157_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00158_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00159_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00160_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00161_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00162_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00163_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00164_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00165_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00166_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00167_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00168_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00169_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00170_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00171_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00172_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00173_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00174_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00175_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00176_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00177_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00178_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00179_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00180_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00181_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00182_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00183_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00184_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00185_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00186_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00187_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00188_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00189_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00190_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00191_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00192_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00193_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00194_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00195_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00196_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00197_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00198_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00199_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00200_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00201_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00202_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00203_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00204_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00205_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00206_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00207_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00208_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00209_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00210_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00211_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00212_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00213_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00214_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00215_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00216_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00217_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00218_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00219_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00220_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00221_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00222_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00223_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00224_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00225_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00226_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00227_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00228_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00229_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00230_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00231_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00232_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00233_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00234_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00235_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00236_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00237_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00238_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00239_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00240_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00241_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00242_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00243_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00244_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00245_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00246_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00247_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00248_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00249_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00250_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00251_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00252_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00253_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00254_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00255_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00256_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00257_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00258_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00259_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00260_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00261_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00262_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00263_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00264_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00265_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00266_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00267_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00268_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00269_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00270_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00271_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00272_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00273_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00274_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00275_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00276_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00277_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00278_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00279_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00280_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00281_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00282_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00283_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00284_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00285_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00286_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00287_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00288_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00289_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00290_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00291_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00292_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00293_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00294_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00295_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00296_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00297_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00298_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00299_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00300_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00301_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00302_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00303_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00304_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00305_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00306_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00307_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00308_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00309_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00310_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00311_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00312_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/00313_original_size_mask.png
# ...
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02497_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02498_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02499_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02500_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02501_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02502_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02503_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02504_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02505_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02506_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02507_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02508_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02509_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02510_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02511_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02512_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02513_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02514_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02515_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02516_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02517_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02518_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02519_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02520_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02521_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02522_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02523_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02524_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02525_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02526_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02527_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02528_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02529_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02530_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02531_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02532_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02533_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02534_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02535_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02536_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02537_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02538_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02539_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02540_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02541_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02542_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02543_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02544_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02545_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02546_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02547_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02548_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02549_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02550_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02551_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02552_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02553_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02554_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02555_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02556_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02557_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02558_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02559_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02560_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02561_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02562_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02563_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02564_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02565_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02566_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02567_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02568_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02569_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02570_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02571_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02572_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02573_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02574_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02575_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02576_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02577_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02578_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02579_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02580_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02581_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02582_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02583_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02584_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02585_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02586_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02587_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02588_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02589_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02590_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02591_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02592_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02593_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02594_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02595_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02596_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02597_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02598_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02599_original_size_mask.png
# Original-sized mask saved: /mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask/02600_original_size_mask.png

# %%
import os
import numpy as np
import cv2
from shapely.geometry import Polygon

def mask_to_polygons(mask):
    '''
    Convierte una máscara de imagen en polígonos. Devuelve una lista de polígonos de shapely.
    
    Args:
        mask (numpy array): Máscara en escala de grises.
    '''
    
    # Calcula los contornos 
    mask = mask.astype(bool)
    contours, _ = cv2.findContours(mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Convertimos los contornos a polígonos de shapely
    polygons = []
    for contour in contours:
        try:
            polygon = contour.reshape(-1, 2).tolist()
        
            # Convertimos a objeto polígono de shapely
            polygon_shapely = Polygon(polygon)
            simplified_polygon = polygon_shapely.simplify(0.85, preserve_topology=True)
            polygons.append(simplified_polygon)
        except Exception as e:
            pass

    return polygons

def process_masks_in_folder(mask_folder, output_folder):
    '''
    Procesa todas las máscaras en una carpeta y crea un archivo de texto para cada imagen con los polígonos.
    
    Args:
        mask_folder (str): Ruta a la carpeta de máscaras.
        output_folder (str): Ruta a la carpeta donde se guardarán los archivos de texto.
    '''
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for mask_filename in os.listdir(mask_folder):
        if not mask_filename.endswith('.png'):
            continue

        mask_path = os.path.join(mask_folder, mask_filename)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        polygons = mask_to_polygons(mask)
        
        # Assuming the output filename should follow the pattern without the '_original_size_mask' suffix
        output_filename = mask_filename.replace('_original_size_mask', '').replace('.png', '.txt')
        output_path = os.path.join(output_folder, output_filename)
        
        with open(output_path, 'w') as f:
            for poly in polygons:
                f.write('0 ' + ' '.join(f"{int(coord[0])} {int(coord[1])}" for coord in poly.exterior.coords[:-1]) + '\n')

# Rutas a las carpetas
mask_folder = '/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/original_sized_mask'
output_folder = '/mnt/DATA/dronetracking/Abhin/segement&detect/detection_DUT/val/mask_polygon/norm_polygons'

process_masks_in_folder(mask_folder, output_folder)
